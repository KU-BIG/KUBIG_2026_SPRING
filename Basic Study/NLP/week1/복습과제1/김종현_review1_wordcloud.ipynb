# %% [markdown]
# ##0. GOAL
# 연주는 부쩍 헬스에 관심이 많이 생겼다고 합니다.
# 주변 헬스인들에게 이 사실을 알리니, 프로틴 보충제 사이트를 추천해주더군요.
#
# 며칠 전 텍스트 전처리를 배운 준석이는 해당 사이트에서 보충제 리뷰를 크롤링해와 워드클라우드를 그려보기로 결심합니다.
#
# 파이프라인은 다음과 같습니다.
#
#  1. 정규표현식으로 한글만 추린다
#  2. 띄어쓰기를 교정한다(PyKospacing)
#  3. 형태소로 토큰화한다(okt)
#  4. 불용어를 제거한다
#  5. 원하는 단어를 Konlpy 사전에 추가한다
#  6. 워드클라우드를 그린다

# %% [markdown]
# ##1. import, load data

# %%
# !pip install konlpy
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from konlpy) (1.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from konlpy) (6.0.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.12/dist-packages (from konlpy) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from JPype1>=0.7.0->konlpy) (25.0)
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-rg0ooe88
#   Running command git clone --filter=blob:none --quiet https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-rg0ooe88
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit b32a889cbd10b006d2f4aba118f0cd5b677e2979
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow>=2.16.2 in /usr/local/lib/python3.12/dist-packages (from pykospacing==0.5) (2.19.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from pykospacing==0.5) (3.15.1)
# Collecting argparse>=1.1.0 (from pykospacing==0.5)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.12/dist-packages (from h5py>=3.10.0->pykospacing==0.5) (2.0.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (3.10.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=2.16.2->pykospacing==0.5) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.16.2->pykospacing==0.5) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.16.2->pykospacing==0.5) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.16.2->pykospacing==0.5) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.16.2->pykospacing==0.5) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.16.2->pykospacing==0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.16.2->pykospacing==0.5) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow>=2.16.2->pykospacing==0.5) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.16.2->pykospacing==0.5) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.16.2->pykospacing==0.5) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.16.2->pykospacing==0.5) (0.1.2)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %%
import pandas as pd
import numpy as np
import re
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/protein.csv")

# %%
df.head()
# Out:
#    Unnamed: 0            title  \
# 0           0  처음 사먹어 보는데 맛있네요
# 1           1   말해 뭐합니까 ㅋㅋㅋ 역시
# 2           2              좋넹요
# 3           3         매우 만족합니다
# 4           4             마싯어요
#
#                                              content  \
# 0                              맛이 좋아서 꾸준히 먹고 있습니다.^^
# 1  가성비 갑 제품 + 맛도 다양해서 ㅋㅋㅋ 항상 구매하고 있습니다요! \n\n    ...
# 2              맛있습니다. 저번에 말차라떼도 먹어봤는데 그것보다 더 나은거 같네요
# 3  5키로는 정말 엄청크네요.\n    평점이 좋아서 스트로베리크림으로 주문했는데 좋습...
# 4                   약간 달긴 하지만 물에 잘 녹고 가루날림이 거의없어 좋아요
#
#                                                 text
# 0               처음 사먹어 보는데 맛있네요맛이 좋아서 꾸준히 먹고 있습니다.^^
# 1  말해 뭐합니까 ㅋㅋㅋ 역시가성비 갑 제품 + 맛도 다양해서 ㅋㅋㅋ 항상 구매하고 있...
# 2           좋넹요맛있습니다. 저번에 말차라떼도 먹어봤는데 그것보다 더 나은거 같네요
# 3  매우 만족합니다5키로는 정말 엄청크네요.\n    평점이 좋아서 스트로베리크림으로 ...
# 4               마싯어요약간 달긴 하지만 물에 잘 녹고 가루날림이 거의없어 좋아요

# %% [markdown]
# ## 2. 정규표현식으로 한글 단어만 남기기
#
# 이제 정규표현식으로 한글 단어만 남기고 모두 제외합니다.

# %%
def extract_hangul(text):
  hangul = re.sub('[^가-힣]', ' ', text)
  return hangul

# %%
example = extract_hangul(df['text'][1])
print("전처리 이전: ",df['text'][1])
print("전처리 이후: ",example)
# Out:
# 전처리 이전:  말해 뭐합니까 ㅋㅋㅋ 역시가성비 갑 제품 + 맛도 다양해서 ㅋㅋㅋ 항상 구매하고 있습니다요!
#
#     스트로베리 크림치즈가 가장 맛있었네요!
# 전처리 이후:  말해 뭐합니까     역시가성비 갑 제품   맛도 다양해서     항상 구매하고 있습니다요        스트로베리 크림치즈가 가장 맛있었네요

# %% [markdown]
# ## 3. 띄어쓰기 교정(PyKoSpacing)
#
# `PyKoSpacing`은 띄어쓰기가 되지 않은 문장을 띄어쓰기가 된 문장으로 교정해주는 패키지입니다다. 앞서 한글 외 다른 문자를 공백으로 치환했는데, 중첩된 공백들도 이 띄어쓰기 교정으로 하나의 공백으로 바꿔줄 수 있습니다.

# %%
from pykospacing import Spacing
spacing = Spacing()

# %%
def spacing_text(text):
  spaced_text = spacing(text)
  return spaced_text

# %%
spaced = spacing_text(example)
print("전처리 이전: ",example)
print("전처리 이후: ",spaced)
# Out:
# 전처리 이전:  말해 뭐합니까     역시가성비 갑 제품   맛도 다양해서     항상 구매하고 있습니다요        스트로베리 크림치즈가 가장 맛있었네요
# 전처리 이후:  말해 뭐 합니까 역시 가성비 갑 제품 맛도 다양해서 항상 구매하고 있습니다 요 스트로베리 크림치즈가 가장 맛있었네요

# %% [markdown]
# ## 4. 형태소 분석기(okt)
#
# 한국어에서 토큰화를 해주는 대표적인 도구는 `konlpy`입니다. 가장 대표적인 형태소 분석기는 `Okt` 모델입니다.

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
def extract_morphs(text):
  morphs_ = okt.morphs(text, stem=True)
  return morphs_

# %%
morphs_ = extract_morphs(spaced)
print("전처리 이전: ",spaced)
print("전처리 이후: ",morphs_)
# Out:
# 전처리 이전:  말해 뭐 합니까 역시 가성비 갑 제품 맛도 다양해서 항상 구매하고 있습니다 요 스트로베리 크림치즈가 가장 맛있었네요
# 전처리 이후:  ['말', '하다', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '있다', '요', '스트로베리', '크림', '치즈', '가', '가장', '맛있다']

# %% [markdown]
# ## 5. 불용어 제거
#
# 분석에 있어 큰 의미가 없는 '불용어(stopword)'를 지정해줘야 합니다. '하다', '도', '는', '이다' 등 의미가 없는 어미나 조사같은 것을 지워주기로 합니다.
#
# 불용어 참고 사이트: https://www.ranks.nl/stopwords/korean
#
# 위 불용어 자료에서 몇 개의 단어를 추가해서 저장해두었습니다.

# %%
with open('/content/stopword.txt') as f:
    list_file = f.readlines()

stopwords_list = []
for stopword in list_file:
  stopwords = re.sub('[\n]', '', stopword)
  stopwords_list.append(stopwords)

def remove_stopwords(text):
  remove_stop = [x for x in text if x not in stopwords_list]
  return remove_stop

# %%
remove_stop = remove_stopwords(morphs_)
print("전처리 이전: ",morphs_)
print("전처리 이후: ",remove_stop)
# Out:
# 전처리 이전:  ['말', '하다', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '있다', '요', '스트로베리', '크림', '치즈', '가', '가장', '맛있다']
# 전처리 이후:  ['말', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '요', '스트로베리', '크림', '치즈', '가장', '맛있다']

# %% [markdown]
# 추가적으로, 불용어로만 걸러내기엔 한계가 있고 아예 한 글자 단어들을 전부 없애주는 것이 나은 경우가 있습니다. 하지만, '맛', '향', '짱'과 같은 핵심적인 단어들은 남겨두기로 했다.

# %%
def remove_one(text):
  except_list = ['맛','향','짱']
  remove_one_ = [x for x in text if len(x)>1 or x in except_list]
  return remove_one_

# %%
remove_one_ = remove_one(remove_stop)
print("전처리 이전: ",remove_stop)
print("전처리 이후: ",remove_one_)
# Out:
# 전처리 이전:  ['말', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '요', '스트로베리', '크림', '치즈', '가장', '맛있다']
# 전처리 이후:  ['니까', '역시', '가성비', '제품', '맛', '다양하다', '항상', '구매', '하고', '스트로베리', '크림', '치즈', '가장', '맛있다']

# %% [markdown]
# 그런데 몇 단어들을 찾아보니 `가성비`는 `가`, `성비`가 나뉘고 `프로틴`은 `프로`, `틴`이 나뉘는 안타까운 상황이 발생했습니다.
#
# 이런 경우, konlpy 사전에 직접 단어를 등재시키는 방법이 있습니다.
#
# 아래처럼 `os` 모듈을 사용하여 코랩 패키지에 저장된 konlpy 폴더에 손을 대는 방식입니다.
#
# 우선 `chdir`로 경로를 이동해주고 `makedirs`로 임시폴더를 만들어준 후. 이 임시폴더에서 단어 사전을 수정한 뒤 원본 폴더에 저장해줍니다.
#
# ** FileNotFoundError가 발생하는 경우 아래 directory에서 python 버전이 잘못된 경우일 수 있습니다.

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
import os

os.chdir('/usr/local/lib/python3.12/dist-packages/konlpy/java')
os.getcwd()
os.makedirs('./aaaa')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipython-input-1226623797.py in <cell line: 0>()
#       3 os.chdir('/usr/local/lib/python3.12/dist-packages/konlpy/java')
#       4 os.getcwd()
# ----> 5 os.makedirs('./aaaa')
#
# /usr/lib/python3.12/os.py in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: './aaaa'

# %%
os.chdir('/usr/local/lib/python3.12/dist-packages/konlpy/java/aaaa') #임시 폴더로 이동
os.getcwd()
# Out:
# '/usr/local/lib/python3.12/dist-packages/konlpy/java/aaaa'

# %% [markdown]
# 임시폴더에 konlpy 사전 파일의 압축을 풀어줍니다.

# %%
# !jar xvf ../open-korean-text-2.1.0.jar
# Out:
#   created: META-INF/
#  inflated: META-INF/MANIFEST.MF
#   created: org/
#   created: org/openkoreantext/
#   created: org/openkoreantext/processor/
#   created: org/openkoreantext/processor/normalizer/
#   created: org/openkoreantext/processor/phrase_extractor/
#   created: org/openkoreantext/processor/qa/
#   created: org/openkoreantext/processor/stemmer/
#   created: org/openkoreantext/processor/tokenizer/
#   created: org/openkoreantext/processor/tools/
#   created: org/openkoreantext/processor/util/
#   created: org/openkoreantext/processor/util/adjective/
#   created: org/openkoreantext/processor/util/adverb/
#   created: org/openkoreantext/processor/util/auxiliary/
#   created: org/openkoreantext/processor/util/freq/
#   created: org/openkoreantext/processor/util/josa/
#   created: org/openkoreantext/processor/util/noun/
#   created: org/openkoreantext/processor/util/substantives/
#   created: org/openkoreantext/processor/util/typos/
#   created: org/openkoreantext/processor/util/verb/
#  inflated: org/openkoreantext/processor/KoreanPosJava.class
#  inflated: org/openkoreantext/processor/KoreanTokenJava.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor$.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessorJava.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase$.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer$.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet$.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime$.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets.class
#  inflated: org/openkoreantext/processor/qa/KoreanProcessorSandbox$.class
#  inflated: org/openkoreantext/processor/qa/KoreanProcessorSandbox.class
#  inflated: org/openkoreantext/processor/stemmer/KoreanStemmer$.class
#  inflated: org/openkoreantext/processor/stemmer/KoreanStemmer.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunk$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunk.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanDetokenizer$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanDetokenizer.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer.class
#  inflated: org/openkoreantext/processor/tokenizer/ParsedChunk$.class
#  inflated: org/openkoreantext/processor/tokenizer/ParsedChunk.class
#  inflated: org/openkoreantext/processor/tokenizer/Sentence$.class
#  inflated: org/openkoreantext/processor/tokenizer/Sentence.class
#  inflated: org/openkoreantext/processor/tokenizer/TokenizerProfile$.class
#  inflated: org/openkoreantext/processor/tokenizer/TokenizerProfile.class
#  inflated: org/openkoreantext/processor/tools/CreateChunkParsingCandidates$.class
#  inflated: org/openkoreantext/processor/tools/CreateChunkParsingCandidates.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample$.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample$.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample$.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples.class
#  inflated: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries$.class
#  inflated: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries.class
#  inflated: org/openkoreantext/processor/tools/Runnable.class
#  inflated: org/openkoreantext/processor/tools/UpdateAllTheExamples$.class
#  inflated: org/openkoreantext/processor/tools/UpdateAllTheExamples.class
#  inflated: org/openkoreantext/processor/util/adjective/adjective.txt
#  inflated: org/openkoreantext/processor/util/adverb/adverb.txt
#  inflated: org/openkoreantext/processor/util/auxiliary/conjunctions.txt
#  inflated: org/openkoreantext/processor/util/auxiliary/determiner.txt
#  inflated: org/openkoreantext/processor/util/auxiliary/exclamation.txt
#  inflated: org/openkoreantext/processor/util/CharacterUtils$CharacterBuffer.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils$Java4CharacterUtils.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils$Java5CharacterUtils.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$1.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EmptyCharArrayMap.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EntryIterator.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EntrySet.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$MapEntry.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$UnmodifiableCharArrayMap.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap.class
#  inflated: org/openkoreantext/processor/util/CharArraySet.class
#  inflated: org/openkoreantext/processor/util/example_chunks.txt
#  inflated: org/openkoreantext/processor/util/example_tweets.txt
#  inflated: org/openkoreantext/processor/util/freq/entity-freq.txt.gz
#  inflated: org/openkoreantext/processor/util/Hangul$.class
#  inflated: org/openkoreantext/processor/util/Hangul$DoubleCoda$.class
#  inflated: org/openkoreantext/processor/util/Hangul$DoubleCoda.class
#  inflated: org/openkoreantext/processor/util/Hangul$HangulChar$.class
#  inflated: org/openkoreantext/processor/util/Hangul$HangulChar.class
#  inflated: org/openkoreantext/processor/util/Hangul.class
#  inflated: org/openkoreantext/processor/util/josa/josa.txt
#  inflated: org/openkoreantext/processor/util/KoreanConjugation$.class
#  inflated: org/openkoreantext/processor/util/KoreanConjugation.class
#  inflated: org/openkoreantext/processor/util/KoreanDictionaryProvider$.class
#  inflated: org/openkoreantext/processor/util/KoreanDictionaryProvider.class
#  inflated: org/openkoreantext/processor/util/KoreanPos$.class
#  inflated: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie$.class
#  inflated: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie.class
#  inflated: org/openkoreantext/processor/util/KoreanPos.class
#  inflated: org/openkoreantext/processor/util/KoreanSubstantive$.class
#  inflated: org/openkoreantext/processor/util/KoreanSubstantive.class
#  inflated: org/openkoreantext/processor/util/noun/bible.txt
#  inflated: org/openkoreantext/processor/util/noun/company_names.txt
#  inflated: org/openkoreantext/processor/util/noun/congress.txt
#  inflated: org/openkoreantext/processor/util/noun/entities.txt
#  inflated: org/openkoreantext/processor/util/noun/foreign.txt
#  inflated: org/openkoreantext/processor/util/noun/geolocations.txt
#  inflated: org/openkoreantext/processor/util/noun/kpop.txt
#  inflated: org/openkoreantext/processor/util/noun/lol.txt
#  inflated: org/openkoreantext/processor/util/noun/names.txt
#  inflated: org/openkoreantext/processor/util/noun/nouns.txt
#  inflated: org/openkoreantext/processor/util/noun/pokemon.txt
#  inflated: org/openkoreantext/processor/util/noun/profane.txt
#  inflated: org/openkoreantext/processor/util/noun/slangs.txt
#  inflated: org/openkoreantext/processor/util/noun/spam.txt
#  inflated: org/openkoreantext/processor/util/noun/twitter.txt
#  inflated: org/openkoreantext/processor/util/noun/wikipedia_title_nouns.txt
#  inflated: org/openkoreantext/processor/util/substantives/family_names.txt
#  inflated: org/openkoreantext/processor/util/substantives/given_names.txt
#  inflated: org/openkoreantext/processor/util/substantives/modifier.txt
#  inflated: org/openkoreantext/processor/util/substantives/suffix.txt
#  inflated: org/openkoreantext/processor/util/typos/typos.txt
#  inflated: org/openkoreantext/processor/util/verb/eomi.txt
#  inflated: org/openkoreantext/processor/util/verb/pre_eomi.txt
#  inflated: org/openkoreantext/processor/util/verb/verb.txt
#  inflated: org/openkoreantext/processor/util/verb/verb_prefix.txt
#   created: META-INF/maven/
#   created: META-INF/maven/org.openkoreantext/
#   created: META-INF/maven/org.openkoreantext/open-korean-text/
#  inflated: META-INF/maven/org.openkoreantext/open-korean-text/pom.xml
#  inflated: META-INF/maven/org.openkoreantext/open-korean-text/pom.properties

# %% [markdown]
# 압축이 잘 풀렸으니 이제 명사들이 등재되어 있는 names.txt를 열어봅니다.

# %%
with open(f"/usr/local/lib/python3.12/dist-packages/konlpy/java/aaaa/org/openkoreantext/processor/util/noun/names.txt") as f:
    data = f.read()

# %% [markdown]
# 아래처럼 다양한 단어들이 저장되어있는 것을 볼 수 있다. 여러 사용자들의 니즈를 반영하여 몇 단어들이 추가된 것으로 보입니다.

# %%
data
# Out:
# '가몽\n가온\n갓세븐\n강새이\n게임닉가\n관우\n귀여미\n규\n김유이\n김준면\n까까런\n노컷\n누너예\n니노\n다마고치\n다이무스\n대학생\n데이브\n도요토미\n동운\n동이\n두주니\n디시인사이드\n디오\n라몹\n라스\n라옵\n멍구\n메이든\n명덕\n명량\n문민정부\n미네\n방엘리\n병헌\n붓다\n비정상회담\n빼빼로\n삼풍\n샤인온미\n성식\n성열\n세라문\n세라복\n세종대왕\n손권\n손책\n쇼미더머니\n쇼챔\n순규\n스라소니\n신동아\n신쓰패밀리\n신아라\n아베\n안상홍\n안홍준\n여누\n여랑\n여포\n연합\n오꾸닭\n요섭\n웃찾사\n원식\n유병언\n유비\n유이\n윤기형\n이나단\n이명박\n이완용\n임창용\n자괴\n자니윤\n자대련\n자유\n재중이\n전교조\n정윤회\n제갈량\n조자룡\n조조\n준면\n지오디\n지존파\n진영오\n차작가\n차트\n창섭\n챠트\n첸\n코르사주\n하무열\n하용파쿠\n혁재\n현이\n현태\n혜미\n프로틴\n가성비\n밀크티\n프로틴\n가성비\n밀크티\n'

# %% [markdown]
# 일단 세 개의 단어를 추가해보도록 합시다. 그리고 쓰기 모드로 변경하여 새롭게 파일을 저장합니다.
#
# 예시로는 아래 세 가지 단어를 넣었지만, 여러분께서 마음껏 원하는 단어를 넣어보셔도 좋습니다.

# %%
data += '프로틴\n가성비\n밀크티\n'

with open("/usr/local/lib/python3.12/dist-packages/konlpy/java/aaaa/org/openkoreantext/processor/util/noun/names.txt", 'w') as f:
    f.write(data)

# %% [markdown]
# 이제 다시 파일을 압축시키면 완료! 런타임을 재실행해야 제대로 반영이 됩니다.
#
# 1. 메뉴 바에서 **런타임** 클릭
# 2. 드롭다운 메뉴에서 **세션 다시 시작**을 선택

# %%
# !jar cvf ../open-korean-text-2.1.0.jar *
# Out:
# added manifest
# adding: drive/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/.shortcut-targets-by-id/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/MyDrive/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/MyDrive/Colab Notebooks/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/MyDrive/Portfolio/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/MyDrive/Portfolio/Economics Paper/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/MyDrive/Portfolio/Kernel PCA-MATH535/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/MyDrive/Portfolio/Optimization Algorithm-Numerical Analysis/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/MyDrive/포트폴리오/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/MyDrive/포트폴리오/matlab handmade function/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/MyDrive/포트폴리오/수치해석_코딩과제/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Encrypted/MyDrive/ㅇㅇ/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Trash-0/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Trash-0/files/(in = 0) (out= 0)(stored 0%)
# adding: drive/.Trash-0/info/(in = 0) (out= 0)(stored 0%)
# adding: drive/.shortcut-targets-by-id/(in = 0) (out= 0)(stored 0%)
# adding: drive/MyDrive/(in = 0) (out= 0)(stored 0%)
# adding: drive/MyDrive/1766638479150.jpg(in = 161667) (out= 161433)(deflated 0%)
# adding: drive/MyDrive/20230216_182031.jpg(in = 229740) (out= 227854)(deflated 0%)
# adding: drive/MyDrive/20240513_120216.jpg(in = 2793888) (out= 2777555)(deflated 0%)
# adding: drive/MyDrive/20240513_230603.jpg(in = 3501467) (out= 3486572)(deflated 0%)
# adding: drive/MyDrive/9eab2d4e-d0fb-4f53-bd94-f2fabfc02e33-2 (1) (1).pdf(in = 83082) (out= 73959)(deflated 10%)
# adding: drive/MyDrive/9eab2d4e-d0fb-4f53-bd94-f2fabfc02e33-2 (1).pdf(in = 83082) (out= 73959)(deflated 10%)
# adding: drive/MyDrive/Colab Notebooks/(in = 0) (out= 0)(stored 0%)
# adding: drive/MyDrive/Colab Notebooks/15기_멤버_코딩테스트_답지.ipynb(in = 401653) (out= 224132)(deflated 44%)
# adding: drive/MyDrive/Colab Notebooks/15기_멤버_코딩테스트_문제지.ipynb(in = 272985) (out= 153020)(deflated 43%)
# adding: drive/MyDrive/Colab Notebooks/16기_멤버_코딩테스트_문제지.ipynb(in = 239233) (out= 166964)(deflated 30%)
# adding: drive/MyDrive/Colab Notebooks/16기_멤버_코딩테스트_문제지.ipynb의 사본(in = 233882) (out= 165221)(deflated 29%)
# adding: drive/MyDrive/Colab Notebooks/25_S_NLP_WEEK1_복습과제_1_2.ipynb의 사본(in = 72456) (out= 46930)(deflated 35%)
# adding: drive/MyDrive/Colab Notebooks/25_S_NLP_WEEK3_복습과제1_RNN_LSTM_numpy.ipynb(in = 313707) (out= 231012)(deflated 26%)
# adding: drive/MyDrive/Colab Notebooks/25_S_NLP_WEEK3_복습과제2_RNN_LSTM_GRU_senti.ipynb(in = 301056) (out= 46376)(deflated 84%)
# adding: drive/MyDrive/Colab Notebooks/25_S_NLP_WEEK3_예습과제1_attention.ipynb(in = 169574) (out= 73315)(deflated 56%)
# adding: drive/MyDrive/Colab Notebooks/25_S_NLP_WEEK5_복습과제1_BERTfinetuning.ipynb(in = 179822) (out= 65327)(deflated 63%)
# adding: drive/MyDrive/Colab Notebooks/25_S_NLP_WEEK5_복습과제2_언어모델에서의_자연어_생성_전략.ipynb(in = 37488) (out= 11751)(deflated 68%)
# adding: drive/MyDrive/Colab Notebooks/NLP Week 2 복습과제1 IMDB.ipynb(in = 79310) (out= 18232)(deflated 77%)
# adding: drive/MyDrive/Colab Notebooks/NLP Week 2 복습과제2 FastText Word2Vec.ipynb(in = 56414) (out= 16533)(deflated 70%)
# adding: drive/MyDrive/Colab Notebooks/NLP Week 2 복습과제3 Word2Vec.ipynb(in = 377036) (out= 229434)(deflated 39%)
# adding: drive/MyDrive/Colab Notebooks/NLP Week 2 예습과제1 RNN LSTM (1).ipynb(in = 532945) (out= 368542)(deflated 30%)
# adding: drive/MyDrive/Colab Notebooks/NLP Week 2 예습과제1 RNN LSTM.ipynb(in = 513144) (out= 354432)(deflated 30%)
# adding: drive/MyDrive/Colab Notebooks/Untitled(in = 306) (out= 211)(deflated 31%)
# adding: drive/MyDrive/Colab Notebooks/Untitled0.ipynb(in = 362) (out= 227)(deflated 37%)
# adding: drive/MyDrive/Colab Notebooks/Untitled1.ipynb(in = 7589) (out= 2870)(deflated 62%)
# adding: drive/MyDrive/Colab Notebooks/Untitled2.ipynb(in = 23594) (out= 4116)(deflated 82%)
# adding: drive/MyDrive/Colab Notebooks/Untitled3.ipynb(in = 12029) (out= 3986)(deflated 66%)
# adding: drive/MyDrive/Colab Notebooks/Untitled4.ipynb(in = 361172) (out= 67982)(deflated 81%)
# adding: drive/MyDrive/Colab Notebooks/Untitled5.ipynb(in = 36334) (out= 9755)(deflated 73%)
# adding: drive/MyDrive/Colab Notebooks/Untitled6.ipynb(in = 4550544) (out= 135640)(deflated 97%)
# adding: drive/MyDrive/Colab Notebooks/Untitled6.ipynb의 사본(in = 49352) (out= 10686)(deflated 78%)
# adding: drive/MyDrive/Colab Notebooks/bertopic_code.ipynb(in = 275769) (out= 47725)(deflated 82%)
# adding: drive/MyDrive/Colab Notebooks/bertopiconkornews (1).ipynb(in = 385910) (out= 71631)(deflated 81%)
# adding: drive/MyDrive/Colab Notebooks/bertopiconkornews (2).ipynb(in = 375880) (out= 68363)(deflated 81%)
# adding: drive/MyDrive/Colab Notebooks/bertopiconkornews.ipynb(in = 375880) (out= 68363)(deflated 81%)
# adding: drive/MyDrive/Colab Notebooks/math535_project_kernel_pca_wdata.ipynb(in = 84393) (out= 12228)(deflated 85%)
# adding: drive/MyDrive/Colab Notebooks/review1_wordcloud.ipynb(in = 59878) (out= 13322)(deflated 77%)
# adding: drive/MyDrive/Colab Notebooks/yelp 토픽모델링 진행안 (0813까지).ipynb의 사본(in = 1534110) (out= 764690)(deflated 50%)
# adding: drive/MyDrive/Colab Notebooks/yelp_academic_dataset_review.json(in = 5341868833) (out= 2190922863)(deflated 58%)
# adding: drive/MyDrive/Colab Notebooks/yelp_academic_dataset_user.json(in = 3363329011) (out= 1971559962)(deflated 41%)
# adding: drive/MyDrive/Colab Notebooks/yelp_토픽모델링_진행안_(0813까지)_ipynb의_사본.ipynb(in = 407535) (out= 45566)(deflated 88%)
# adding: drive/MyDrive/Colab Notebooks/yelp_토픽모델링_진행안_(0814까지)_ipynb의_사본 (1).ipynb(in = 386898) (out= 58348)(deflated 84%)
# adding: drive/MyDrive/Colab Notebooks/yelp_토픽모델링_진행안_(0814까지)_ipynb의_사본.ipynb(in = 1589535) (out= 766483)(deflated 51%)
# adding: drive/MyDrive/Colab Notebooks/yelp_토픽모델링_진행안_(0814까지)_ipynb의_사본.ipynb의 사본(in = 386972) (out= 58398)(deflated 84%)
# adding: drive/MyDrive/Colab Notebooks/yelp_토픽모델링_진행안_(0814까지)_ipynb의_사본_ipynb의_사본.ipynb(in = 530447) (out= 66624)(deflated 87%)
# adding: drive/MyDrive/OhAlgebraicTopology필기 (2) (1).pdf(in = 37012974) (out= 33377263)(deflated 9%)
# adding: drive/MyDrive/OhAlgebraicTopology필기 (2).pdf(in = 24492898) (out= 21216449)(deflated 13%)
# adding: drive/MyDrive/OhDeepLearning.pdf(in = 133684191) (out= 112228628)(deflated 16%)
# adding: drive/MyDrive/OhTopology.pdf(in = 23604172) (out= 17710701)(deflated 24%)
# adding: drive/MyDrive/Portfolio/(in = 0) (out= 0)(stored 0%)
# adding: drive/MyDrive/Portfolio/Economics Paper/(in = 0) (out= 0)(stored 0%)
# adding: drive/MyDrive/Portfolio/Economics Paper/국소투영모형을 이용한 원유 공급충격에 대한 미국 수요견인 인플레이션의 반응 분석.pdf(in = 1945185) (out= 1077105)(deflated 44%)
# adding: drive/MyDrive/Portfolio/Economics Paper/내생적 통화공급과 통화량 지표의 의의.pdf(in = 1403136) (out= 954005)(deflated 32%)
# adding: drive/MyDrive/Portfolio/Economics Paper/베이지안 통계학 정리_42기 김종현.pdf(in = 351300) (out= 286466)(deflated 18%)
# adding: drive/MyDrive/Portfolio/Economics Paper/한국의 통화정책 불확실성과 조건부 포워드 가이던스 실효성 분석.pdf(in = 627324) (out= 543731)(deflated 13%)
# adding: drive/MyDrive/Portfolio/Kernel PCA-MATH535/(in = 0) (out= 0)(stored 0%)
# adding: drive/MyDrive/Portfolio/Kernel PCA-MATH535/math535_codes_kernelpca_wdata (1).ipynb(in = 16247783) (out= 11817846)(deflated 27%)
# adding: drive/MyDrive/Portfolio/Kernel PCA-MATH535/math535_presentation_slides (1).pdf(in = 1179776) (out= 1042300)(deflated 11%)
# adding: drive/MyDrive/Portfolio/Kernel PCA-MATH535/math535_project_dataset.zip(in = 12811204) (out= 12741218)(deflated 0%)
# adding: drive/MyDrive/Portfolio/Optimization Algorithm-Numerical Analysis/(in = 0) (out= 0)(stored 0%)
# adding: drive/MyDrive/Portfolio/Optimization Algorithm-Numerical Analysis/SIRwEulermethod-NumericalAnalysis.pdf(in = 319869) (out= 277968)(deflated 13%)
# adding: drive/MyDrive/Portfolio/Optimization Algorithm-Numerical Analysis/finalproject.m(in = 2748) (out= 1145)(deflated 58%)
# adding: drive/MyDrive/Resume_JHKIM (1).pdf(in = 223351) (out= 204917)(deflated 8%)
# adding: drive/MyDrive/Resume_JHKIM.pdf(in = 223351) (out= 204917)(deflated 8%)
# adding: drive/MyDrive/Screenshot_20230206-174356_Chrome.jpg(in = 179001) (out= 137366)(deflated 23%)
# adding: drive/MyDrive/Screenshot_20230512_211311_KakaoTalk.jpg(in = 227977) (out= 191892)(deflated 15%)
# adding: drive/MyDrive/Screenshot_20240519_095144_NAVER.jpg(in = 115860) (out= 72165)(deflated 37%)
# adding: drive/MyDrive/Screenshot_20250501_094056_KakaoTalk.jpg(in = 316320) (out= 267546)(deflated 15%)
# adding: drive/MyDrive/Screenshot_20250930_001153_RunDay.jpg(in = 223442) (out= 192246)(deflated 13%)
# adding: drive/MyDrive/Screenshot_20250930_231933_RunDay.jpg(in = 224376) (out= 192492)(deflated 14%)
# adding: drive/MyDrive/Screenshot_20251001_233721_RunDay.jpg(in = 222786) (out= 191939)(deflated 13%)
# adding: drive/MyDrive/Screenshot_20251003_205848_RunDay.jpg(in = 236464) (out= 205034)(deflated 13%)
# adding: drive/MyDrive/Screenshot_20251004_225943_RunDay.jpg(in = 231709) (out= 200575)(deflated 13%)
# adding: drive/MyDrive/Screenshot_20251005_223702_RunDay.jpg(in = 234771) (out= 203847)(deflated 13%)
# adding: drive/MyDrive/Screenshot_20251006_194919_RunDay.jpg(in = 283972) (out= 244834)(deflated 13%)
# adding: drive/MyDrive/Screenshot_20251007_222349_RunDay.jpg(in = 212763) (out= 183432)(deflated 13%)
# adding: drive/MyDrive/Screenshot_20251008_213928_RunDay.jpg(in = 266601) (out= 233877)(deflated 12%)
# adding: drive/MyDrive/Screenshot_20251011_192223_RunDay.jpg(in = 231706) (out= 200386)(deflated 13%)
# adding: drive/MyDrive/Screenshot_20251013_232652_RunDay (1).jpg(in = 252540) (out= 228098)(deflated 9%)
# adding: drive/MyDrive/Screenshot_20251013_232652_RunDay.jpg(in = 252540) (out= 228098)(deflated 9%)
# adding: drive/MyDrive/malgun.ttf(in = 4337104) (out= 1576560)(deflated 63%)
# adding: drive/MyDrive/protein.csv(in = 488581) (out= 98935)(deflated 79%)
# adding: drive/MyDrive/stopword.txt(in = 7764) (out= 3077)(deflated 60%)
# adding: drive/MyDrive/yelp_academic_dataset_business.json(in = 118863795) (out= 20927906)(deflated 82%)
# adding: drive/MyDrive/강의정보.txt(in = 408) (out= 310)(deflated 24%)
# adding: drive/MyDrive/개념정리.pdf(in = 3920639) (out= 3810733)(deflated 2%)
# adding: drive/MyDrive/개념정리.sdocx(in = 2326203) (out= 2232248)(deflated 4%)
# adding: drive/MyDrive/과제1.pdf(in = 5812516) (out= 5646814)(deflated 2%)
# adding: drive/MyDrive/과제1.sdocx(in = 2469385) (out= 2351545)(deflated 4%)
# adding: drive/MyDrive/과제2.pdf(in = 5159112) (out= 5030343)(deflated 2%)
# adding: drive/MyDrive/과제3.pdf(in = 3834609) (out= 3741351)(deflated 2%)
# adding: drive/MyDrive/과제3.sdocx(in = 2163951) (out= 2081620)(deflated 3%)
# adding: drive/MyDrive/과제4.pdf(in = 5191461) (out= 5049153)(deflated 2%)
# adding: drive/MyDrive/과제4.sdocx(in = 2304763) (out= 2202350)(deflated 4%)
# adding: drive/MyDrive/과제4제대로.sdocx(in = 3011802) (out= 2853352)(deflated 5%)
# adding: drive/MyDrive/과제5.pdf(in = 4114370) (out= 4023524)(deflated 2%)
# adding: drive/MyDrive/과제5.sdocx(in = 2191119) (out= 2127387)(deflated 2%)
# adding: drive/MyDrive/과제5제대로.sdocx(in = 2385369) (out= 2321726)(deflated 2%)
# adding: drive/MyDrive/귀하와 '9eab2d4e-d0fb-4f53-bd94-f2fabfc02e33-2 (1)'을(를) 공유합니다..pdf(in = 83082) (out= 73959)(deflated 10%)
# adding: drive/MyDrive/포트폴리오/(in = 0) (out= 0)(stored 0%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/(in = 0) (out= 0)(stored 0%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/12344.m(in = 84) (out= 60)(deflated 28%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/AddVectPol.m(in = 193) (out= 129)(deflated 33%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/AveTemp.m(in = 374) (out= 159)(deflated 57%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/Chil Temp.m(in = 181) (out= 144)(deflated 20%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/ChilTemp.m(in = 186) (out= 149)(deflated 19%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/Deposit.m(in = 116) (out= 101)(deflated 12%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/Far.m(in = 147) (out= 117)(deflated 20%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/Surface.m(in = 217) (out= 163)(deflated 24%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/Tay.m(in = 112) (out= 96)(deflated 14%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/call.m(in = 208) (out= 129)(deflated 37%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/det2by2.m(in = 59) (out= 51)(deflated 13%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/det3by3.m(in = 220) (out= 119)(deflated 45%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/funcplot.m(in = 74) (out= 63)(deflated 14%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/go.m(in = 133) (out= 111)(deflated 16%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/goo.m(in = 85) (out= 70)(deflated 17%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/innerproduct.m(in = 61) (out= 55)(deflated 9%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/mat.m(in = 256) (out= 143)(deflated 44%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/parallelogram.m(in = 309) (out= 157)(deflated 49%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/quadplot.m(in = 332) (out= 194)(deflated 41%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/quadroot.m(in = 308) (out= 151)(deflated 50%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/quadroots.m(in = 314) (out= 154)(deflated 50%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/seq.m(in = 174) (out= 116)(deflated 33%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/sum2.m(in = 204) (out= 152)(deflated 25%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/test.m(in = 92) (out= 66)(deflated 28%)
# adding: drive/MyDrive/포트폴리오/matlab handmade function/tracker.prefs(in = 645) (out= 371)(deflated 42%)
# adding: drive/MyDrive/포트폴리오/수치해석_코딩과제/(in = 0) (out= 0)(stored 0%)
# adding: drive/MyDrive/포트폴리오/수치해석_코딩과제/수치해석_김종현_2020102585_HW1.pdf(in = 826863) (out= 759466)(deflated 8%)
# adding: drive/MyDrive/포트폴리오/수치해석_코딩과제/수치해석_김종현_2020102585_HW2.pdf(in = 2480227) (out= 2293641)(deflated 7%)
# adding: drive/MyDrive/포트폴리오/수치해석_코딩과제/수치해석_김종현_2020102585_HW3.pdf(in = 1699076) (out= 1538497)(deflated 9%)
# adding: drive/MyDrive/포트폴리오/수치해석_코딩과제/수치해석_김종현_2020102585_HW4.pdf(in = 413446) (out= 367717)(deflated 11%)
# adding: drive/MyDrive/포트폴리오/캐글코딩주소.txt(in = 80) (out= 78)(deflated 2%)
# adding: drive/MyDrive/피렌체 (1).pdf(in = 83082) (out= 73959)(deflated 10%)
# adding: drive/MyDrive/피렌체.pdf(in = 83082) (out= 73959)(deflated 10%)
# adding: drive/MyDrive/ㅇㅇ/(in = 0) (out= 0)(stored 0%)
# adding: drive/MyDrive/ㅇㅇ/20200709_205823.mp4(in = 889405) (out= 886248)(deflated 0%)
# adding: drive/MyDrive/ㅇㅇ/20200709_205940.jpg(in = 125448) (out= 100064)(deflated 20%)
# adding: drive/MyDrive/ㅇㅇ/20200709_205941.mp4(in = 3048189) (out= 3038036)(deflated 0%)
# adding: drive/MyDrive/ㅇㅇ/20200709_210510.mp4(in = 2272741) (out= 2269786)(deflated 0%)
# adding: drive/MyDrive/ㅇㅇ/20200709_210546.mp4(in = 2632930) (out= 2627170)(deflated 0%)
# adding: drive/MyDrive/ㅇㅇ/20200709_210623.mp4(in = 1316870) (out= 1313947)(deflated 0%)
# adding: drive/MyDrive/ㅇㅇ/20200709_210632.mp4(in = 3823950) (out= 3815732)(deflated 0%)
# adding: drive/MyDrive/ㅇㅇ/20200709_210723.mp4(in = 4113327) (out= 4102746)(deflated 0%)
# adding: drive/MyDrive/ㅇㅇ/20200709_214922.mp4(in = 1148348) (out= 1144162)(deflated 0%)
# adding: drive/MyDrive/ㅇㅇ/20200709_215952.mp4(in = 3680913) (out= 3673925)(deflated 0%)
# adding: malgun.ttf(in = 4337104) (out= 1576560)(deflated 63%)
# adding: protein.csv(in = 488581) (out= 98935)(deflated 79%)
# adding: review1_wordcloud.ipynb(in = 17240) (out= 4298)(deflated 75%)
# adding: sample_data/(in = 0) (out= 0)(stored 0%)
# adding: sample_data/README.md(in = 962) (out= 589)(deflated 38%)
# adding: sample_data/anscombe.json(in = 1697) (out= 295)(deflated 82%)
# adding: sample_data/california_housing_test.csv(in = 301141) (out= 71399)(deflated 76%)
# adding: sample_data/california_housing_train.csv(in = 1706430) (out= 362768)(deflated 78%)
# adding: sample_data/mnist_test.csv(in = 18289443) (out= 2206214)(deflated 87%)
# adding: sample_data/mnist_train_small.csv(in = 36523880) (out= 4424103)(deflated 87%)
# adding: stopword.txt(in = 7764) (out= 3077)(deflated 60%)

# %% [markdown]
# 원래 두 단어로 나뉘어서 나오던 것들이 올바르게 한 단어로 출력되는 것을 볼 수 있습니다.

# %%
print(okt.nouns("가성비"))
print(okt.nouns("프로틴"))
# Out:
# ['가성비']
# ['프로틴']

# %% [markdown]
# 전 과정을 하나로 통합하면 아래와 같습니다.

# %%
from konlpy.tag import Okt
okt = Okt()

from pykospacing import Spacing
spacing = Spacing()

except_list = ['맛','향','짱']

with open('/content/stopword.txt') as f:
    list_file = f.readlines()

stopwords_list = []
for stopword in list_file:
  stopwords = re.sub('[\n]', '', stopword)
  stopwords_list.append(stopwords)

def review_to_words(raw_review):
  text = re.sub('[^가-힣]', ' ', raw_review)
  text = spacing(text)
  text = okt.morphs(text, stem=True)
  text = [x for x in text if x not in stopwords_list]
  text = [x for x in text if len(x)>1 or x in except_list]
  text = " ".join(text)
  return text

# %% [markdown]
# 이제 `words_list`를 만들어 전처리한 단어들을 하나의 리스트에 모아줍니다. 띄어쓰기 교정 과정에서 약간 지연됩니다.

# %%
import tqdm
df_len = df.shape[0]
words_list = []
for i in range(df_len):
  words_list.append(review_to_words(df['text'][i]))

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %matplotlib inline
def displayWordCloud(data = None, backgroundcolor = 'white', width=None, height=None):
    wordcloud = WordCloud(font_path = '/content/malgun.ttf',
                          background_color = backgroundcolor,
                          width = width,
                          height = height).generate(data)
    plt.figure(figsize = (15 , 10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
displayWordCloud(data = ' '.join(words_list), width=600, height=400)
