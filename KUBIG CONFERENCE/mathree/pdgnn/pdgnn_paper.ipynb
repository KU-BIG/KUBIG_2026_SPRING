# %% [markdown]
# <a href="https://colab.research.google.com/github/HyunjuYun1009/tda-conference/blob/main/pdgnn/pdgnn_paper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ── 셀 1: 레포 클론 ──
# !git clone https://github.com/pkuyzy/TLC-GNN.git
# %cd TLC-GNN
# Out:
# Cloning into 'TLC-GNN'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 95 (delta 36), reused 77 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (95/95), 5.47 MiB | 22.49 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/TLC-GNN

# %%
# ── 셀 2: torch 확인 (Colab 기본 설치됨) ──
import torch
print(torch.__version__, torch.version.cuda)
# 예: 2.3.0+cu121
# Out:
# 2.10.0+cu128 12.8

# %%
# ── 셀 3: PyG 설치 ──
import torch
v = torch.__version__.split('+')[0]
cuda = 'cu' + torch.version.cuda.replace('.','')

# !pip install torch-scatter torch-sparse torch-cluster torch-spline-conv \
    -f https://data.pyg.org/whl/torch-{v}+{cuda}.html -q
# !pip install torch-geometric gudhi networkx scikit-learn GraphRicciCurvature -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 106.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 131.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 113.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 78.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 91.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 93.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 49.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 15.0 MB/s eta 0:00:00
# ...

# %%
# ── 셀 4: dionysus 패치 적용 ──
from google.colab import files
uploaded = files.upload()  # 다운받은 riccidist2dgm.py 업로드
import shutil
shutil.copy('riccidist2dgm.py', '/content/TLC-GNN/sg2dgm/riccidist2dgm.py')
print("패치 완료")
# Out:
#      <input type="file" id="files-e7f9081c-730a-476a-8ab6-d1f19c140059" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7f9081c-730a-476a-8ab6-d1f19c140059">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ── 셀 5: sg2dgm 빌드 또는 우회 ──
# %cd /content/TLC-GNN/sg2dgm
try:
    # !python setup_PI.py build_ext --inplace
except:
    # !cp persistenceImager.pyx persistenceImager.py
# %cd /content/TLC-GNN
# Out:
# /content/TLC-GNN/sg2dgm
# Compiling PersistenceImager.pyx because it changed.
# [1/1] Cythonizing PersistenceImager.pyx
# /usr/local/lib/python3.12/dist-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /content/TLC-GNN/sg2dgm/PersistenceImager.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# /content/TLC-GNN

# %% [markdown]
# dgformat.py   → /TLC-GNN/sg2dgm/dgformat.py 로 덮어쓰기
#
# riccidist2dgm.py → /TLC-GNN/sg2dgm/riccidist2dgm.py 로 덮어쓰기

# %%
# ── 셀 6: 실행 ──
# !python pipelines.py
# Out:
# ...
# Processing...
# Done!
# 101219
# start writing ricci curvature
# adding edges finished
# computing ricci curvature finished
# having computed: 0 edges, really computed: 0 edges, cost 16.5s
# having computed: 2747000 edges, really computed: 8 edges, cost 17.3s
# having computed: 5494000 edges, really computed: 58 edges, cost 18.6s
# having computed: 5952000 edges, really computed: 68 edges, cost 18.8s
# having computed: 3205000 edges, really computed: 94 edges, cost 19.3s
# having computed: 458000 edges, really computed: 128 edges, cost 20.3s
# having computed: 3663000 edges, really computed: 155 edges, cost 21.1s
# having computed: 916000 edges, really computed: 203 edges, cost 22.1s
# having computed: 4121000 edges, really computed: 247 edges, cost 22.7s
# having computed: 6868000 edges, really computed: 266 edges, cost 23.1s
# having computed: 6410000 edges, really computed: 277 edges, cost 23.3s
# having computed: 4579000 edges, really computed: 310 edges, cost 23.9s
# ...
